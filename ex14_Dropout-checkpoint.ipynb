# %%
# !nvidia-smi
# Out:
# Thu Sep 14 13:52:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 527.27       Driver Version: 527.27       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A4000   WDDM  | 00000000:01:00.0  On |                  Off |
# | 44%   58C    P5    23W / 140W |  15850MiB / 16376MiB |     16%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      3020    C+G   ...3d8bbwe\CalculatorApp.exe    N/A      |
# |    0   N/A  N/A      4932    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      5044      C   ...orflow210Py310\python.exe    N/A      |
# |    0   N/A  N/A      5464      C   ...orflow210Py310\python.exe    N/A      |
# |    0   N/A  N/A      6440      C   ...orflow210Py310\python.exe    N/A      |
# |    0   N/A  N/A      7152    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      8320    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A      9652    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     11040      C   ...orflow210Py310\python.exe    N/A      |
# |    0   N/A  N/A     11312    C+G   ...e\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     12224    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     12820    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     14688    C+G   ...e\Current\LogiOverlay.exe    N/A      |
# |    0   N/A  N/A     15292    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A     16232    C+G   ...ekyb3d8bbwe\HxOutlook.exe    N/A      |
# |    0   N/A  N/A     16364      C   ...orflow210Py310\python.exe    N/A      |
# |    0   N/A  N/A     17664    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     19912    C+G   ...ge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     21072    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     21756    C+G   ...oft\OneDrive\OneDrive.exe    N/A      |
# |    0   N/A  N/A     23328    C+G   ...jt4zspk6g\BudsManager.exe    N/A      |
# |    0   N/A  N/A     23536    C+G   ...\NexonPlug\PlugRender.exe    N/A      |
# |    0   N/A  N/A     24176    C+G   ...ontrols\QuickControls.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical

import numpy as np
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship','truck' ]
NUM_CLASSES = 10


if y_test.shape[1] == 1:
  x_train = x_train/255.
  x_test = x_test/255.
  y_train = to_categorical(y_train, NUM_CLASSES)
  y_test = to_categorical(y_test, NUM_CLASSES)

model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)),
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation = 'relu'),
    keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam',
             loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#epochs 50으로
history = model.fit(x_train, y_train, epochs=3, validation_data=(x_test,y_test))
# Out:
# Epoch 1/3
# 1563/1563 [==============================] - 11s 5ms/step - loss: 1.5021 - accuracy: 0.4511 - val_loss: 1.1489 - val_accuracy: 0.5854
# Epoch 2/3
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0011 - accuracy: 0.6445 - val_loss: 0.9632 - val_accuracy: 0.6623
# Epoch 3/3
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8033 - accuracy: 0.7175 - val_loss: 0.8534 - val_accuracy: 0.7098

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)),
    keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation = 'relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam',
             loss='categorical_crossentropy',
              metrics=['accuracy'])
# epochs 50으로
history2 = model.fit(x_train, y_train, epochs=3, validation_data=(x_test,y_test))
# Out:
# Epoch 1/3
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.8269 - accuracy: 0.3168 - val_loss: 1.4048 - val_accuracy: 0.4837
# Epoch 2/3
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3998 - accuracy: 0.4933 - val_loss: 1.1857 - val_accuracy: 0.5697
# Epoch 3/3
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.2218 - accuracy: 0.5661 - val_loss: 1.0339 - val_accuracy: 0.6293

# %%
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
